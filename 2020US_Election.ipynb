# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

DATA_PATH = 'C:/Users/sbs/anaconda3/envs/tensorflow/Lib'
train_df = pd.read_csv(DATA_PATH + '/2020election.csv')
train_df.head()
# Out:
#            State                                             Source  \
# 0  United States                                                NaN
# 1        Alabama  https://www2.alabamavotes.gov/electionnight/st...
# 2         Alaska  https://www.elections.alaska.gov/results/20GEN...
# 3        Arizona       https://results.arizona.vote/#/featured/18/0
# 4       Arkansas  https://results.enr.clarityelections.com/AR/10...
#
#   Official/Unofficial Total Ballots Counted (Estimate)  \
# 0                 NaN                      158,835,004
# 1          Unofficial                        2,306,587
# 2                 NaN                          367,000
# 3                 NaN                        3,400,000
# 4          Unofficial                        1,212,030
#
#   Vote for Highest Office (President) VEP Turnout Rate  \
# 0                                 NaN            66.4%
# 1                           2,297,295            62.6%
# ...

# %%
print('shape of train_df :', train_df.shape)
print('columns of train_df :', list(train_df.columns))
# Out:
# shape of train_df : (52, 15)
# columns of train_df : ['State', 'Source', 'Official/Unofficial', 'Total Ballots Counted (Estimate)', 'Vote for Highest Office (President)', 'VEP Turnout Rate', 'Voting-Eligible Population (VEP)', 'Voting-Age Population (VAP)', '% Non-citizen', 'Prison', 'Probation', 'Parole', 'Total Ineligible Felon', 'Overseas Eligible', 'State Abv']

# %%
print(train_df.index)
# Out:
# RangeIndex(start=0, stop=52, step=1)

# %%
train_df['State'][1]
# Out:
# 'Alabama'

# %%
train_df['Prison']
# train_df['Probation']
# train_df['Parole']
# Out:
# 0     1,461,074
# 1        25,898
# 2         4,293
# 3        38,520
# 4        17,510
# 5       104,730
# 6        18,905
# 7        13,268
# 8         5,874
# 9             0
# 10       91,674
# 11       50,930
# 12        5,007
# 13        8,378
# 14       38,464
# 15       26,302
# 16        9,216
# 17        9,882
# 18       23,280
# 19       32,267
# 20            0
# 21       18,165
# 22        7,772
# 23       38,183
# 24        9,712
# 25       19,244
# 26       30,148
# 27        3,754
# 28        5,263
# 29       12,399
# 30        2,635
# 31       18,099
# 32        6,887
# 33       42,408
# 34       33,640
# 35        1,679
# 36       49,892
# 37       27,558
# 38       13,795
# 39       44,148
# 40        2,766
# 41       18,587
# 42        3,867
# 43       26,107
# 44      154,913
# 45        6,287
# 46            0
# 47       35,743
# 48       18,777
# 49        6,757
# 50       23,574
# 51        2,488
# Name: Prison, dtype: object

# %%
for i in range(1, len(train_df.index)):
    n1 = train_df['Prison'][i]
    n2 = train_df['Probation'][i]
    n3 = train_df['Parole'][i]
    n4 = int(n1.replace(',','')) + int(n2.replace(',','')) + int(n3.replace(',',''))
#     n = 1
#     if len(n4) > 3:
#         n4 = str(n4)
#         if len(n4) > 3 * n:
#         n4[::-1] + n4(3*n)','
        # n4를 str형태로 변환 -> 뒤에서 3자리마다 ',' 붙여주기
    print('{0} : {1}(Prison), {2}(Probation), {3}(Parole) -> total:{4}'.format(train_df['State'][i], n1, n2, n3, n4))
# Out:
# Alabama : 25,898(Prison), 50,997(Probation), 10,266(Parole) -> total:87161
# Alaska : 4,293(Prison), 2,074(Probation), 1,348(Parole) -> total:7715
# Arizona : 38,520(Prison), 76,844(Probation), 7,536(Parole) -> total:122900
# Arkansas : 17,510(Prison), 36,719(Probation), 24,698(Parole) -> total:78927
# California : 104,730(Prison), 0(Probation), 102,586(Parole) -> total:207316
# Colorado : 18,905(Prison), 0(Probation), 0(Parole) -> total:18905
# Connecticut : 13,268(Prison), 0(Probation), 4,452(Parole) -> total:17720
# Delaware : 5,874(Prison), 14,176(Probation), 350(Parole) -> total:20400
# District of Columbia : 0(Prison), 0(Probation), 0(Parole) -> total:0
# Florida : 91,674(Prison), 205,033(Probation), 4,345(Parole) -> total:301052
# Georgia : 50,930(Prison), 416,771(Probation), 20,426(Parole) -> total:488127
# Hawaii : 5,007(Prison), 0(Probation), 0(Parole) -> total:5007
# Idaho : 8,378(Prison), 34,392(Probation), 5,267(Parole) -> total:48037
# ...
